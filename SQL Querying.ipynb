# %%
# !pip install --force-reinstall ibm_db==3.1.0 ibm_db_sa==0.3.3
# #Ensure we don't load_ext with sqlalchemy>=1.4 (incompadible)
# !pip uninstall sqlalchemy==1.4 -y && pip install sqlalchemy==1.3.24
# !pip install ipython-sql

# %%
import pandas as pd
import numpy as np
import ibm_db,ibm_db_sa
import ibm_db_dbi

# %% [markdown]
# # Connecting to IBM CloudPak DB2

# %%
# %load_ext sql
# run custom file with IBM's CloudPak DB2 credentials - for privacy purposes
# %run hide/IBM_Db2-credentials.py

# %%
# %reload_ext sql
# run custom file with IBM's CloudPak DB2 credentials - for privacy purposes
# %run hide/IBM_Db2-credentials.py

# %%
# %sql ibm_db_sa://{dsn_uid}:{dsn_pwd}@{dsn_hostname}:{dsn_port}/{dsn_database}?security={dsn_security}

# %% [markdown]
# # Querying Data

# %%
# %%sql
# select * from CENSUS_DATA;
# Out:
#  * ibm_db_sa://bvr08213:***@54a2f15b-5c0f-46df-8954-7e38e612c2bd.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:32733/bludb
# Done.
# [(1, 'Rogers Park', 7.699999809265137, 23.600000381469727, 8.699999809265137, 18.200000762939453, 27.5, 23939, 39),
#  (2, 'West Ridge', 7.800000190734863, 17.200000762939453, 8.800000190734863, 20.799999237060547, 38.5, 23040, 46),
#  (3, 'Uptown', 3.799999952316284, 24.0, 8.899999618530273, 11.800000190734863, 22.200000762939453, 35787, 20),
#  (4, 'Lincoln Square', 3.4000000953674316, 10.899999618530273, 8.199999809265137, 13.399999618530273, 25.5, 37524, 17),
#  (5, 'North Center', 0.30000001192092896, 7.5, 5.199999809265137, 4.5, 26.200000762939453, 57123, 6),
#  (6, 'Lake View', 1.100000023841858, 11.399999618530273, 4.699999809265137, 2.5999999046325684, 17.0, 60058, 5),
#  (7, 'Lincoln Park', 0.800000011920929, 12.300000190734863, 5.099999904632568, 3.5999999046325684, 21.5, 71551, 2),
# ...

# %%
census_data = pd.read_sql('select * from CENSUS_DATA',hdbi)
census_data
# Out:
#     COMMUNITY_AREA_NUMBER COMMUNITY_AREA_NAME  PERCENT_OF_HOUSING_CROWDED  \
# 0                       1         Rogers Park                         7.7
# 1                       2          West Ridge                         7.8
# 2                       3              Uptown                         3.8
# 3                       4      Lincoln Square                         3.4
# 4                       5        North Center                         0.3
# ..                    ...                 ...                         ...
# 72                     73   Washington Height                         1.1
# 73                     74     Mount Greenwood                         1.0
# 74                     75         Morgan Park                         0.8
# 75                     76              O Hare                         3.6
# 76                     77           Edgewater                         4.1
#
#     PERCENT_HOUSEHOLDS_BELOW_POVERTY  PERCENT_AGED_16__UNEMPLOYED  \
# ...

# %%
crime_data = pd.read_sql('select * from CRIME_DATA',hdbi)
crime_data
# Out:
#            ID CASE_NUMBER        DATE                     BLOCK  IUCR  \
# 0     3512276    HK587712  2004-08-28        047XX S KEDZIE AVE   890
# 1     3406613    HK456306  2004-06-26  009XX N CENTRAL PARK AVE   820
# 2     8002131    HT233595  2011-04-04        043XX S WABASH AVE   820
# 3     7903289    HT133522  2010-12-30      083XX S KINGSTON AVE   840
# 4    10402076    HZ138551  2016-02-02           033XX W 66TH ST   820
# ..        ...         ...         ...                       ...   ...
# 528  10453948    HZ192829  2016-03-01           028XX E 79TH ST  1055
# 529  10397129    HZ133234  2016-01-29       006XX W HARRISON ST  5114
# 530   3269495    HJ747227  2003-11-08           012XX W 81ST ST   510
# 531  10840565    JA143710  2017-02-06        009XX N KARLOV AVE  5073
# 532   1326195     G021609  2001-01-11       087XX S ESCANABA AV  9901
#
#                          PRIMARY_TYPE  \
# 0                               THEFT
# 1                               THEFT
# ...

# %%
school_data = pd.read_sql('select * from PUBLIC_SCHOOLS',hdbi)
school_data
# Out:
#      SCHOOL_ID                                     NAME_OF_SCHOOL  \
# 0       400018  Austin Business and Entrepreneurship Academy H...
# 1       609674      Chicago Vocational Career Academy High School
# 2       609676    Paul Laurence Dunbar Career Academy High School
# 3       609678      William Jones College Preparatory High School
# 4       609679   Charles Allen Prosser Career Academy High School
# ..         ...                                                ...
# 561     610539                    Marvin Camras Elementary School
# 562     610541            Federico Garcia Lorca Elementary School
# 563     610542                       West Ridge Elementary School
# 564     610543                   Eric Solorio Academy High School
# 565     610544                   Mariano Azuela Elementary School
#
#     ELEMENTARY_MIDDLE_OR_HIGH_SCHOOL          STREET_ADDRESS     CITY STATE  \
# 0                                 HS          231 N Pine Ave  Chicago    IL
# ...

# %%
print(dsn[:15])
# Out:
# DRIVER={IBM DB2

# %% [markdown]
# # Closing Connection

# %%
# closing the connection (session)

connections = %sql -l
[c.session.close() for c in connections.values()]
